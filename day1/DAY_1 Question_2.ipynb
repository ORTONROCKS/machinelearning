# %% [markdown]
#  作業2：申論題目可直接將答案回覆在HW檔案裡面，Jupyter notebook可直接編輯文字。
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 1. 你選的這組資料為何重要
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#
# 3. 蒐集而來的資料型態為何
#
# 4. 這組資料想解決的問題如何評估

# %%
所選數據：HR Analytics: Job Change of Data Scientists

# %%
1. 你選的這組資料為何重要
這組資料包含培訓者的居住城市、學歷、前公司等，
通過數據分析可以人資部門提早對面試者拒絕offer的可能性進行預估，
降低人資部門的培訓的成本即時間。

# %%
2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
通過面試者提供

# %%
3. 蒐集而來的資料型態為何
enrollee_id： 候選人的獨特 ID

城市：城市代碼

city_發展_index：城市發展指數（規模化）

性別：候選人的性別

relevent_experience：候選人的相關經驗

enrolled_university：如果有的話，大學課程的類型

education_level：考生的教育水準

major_discipline：考生教育專業

經驗：候選人多年總經驗

company_size：當前僱主公司沒有員工

company_type： 現任僱主類型

上一份新工作：以前工作和當前工作之間的年份差異

training_hours：培訓時間已滿

目標：0–不尋找工作變化，1–尋找工作變化

# %%
4. 這組資料想解決的問題如何評估
將資料通過建立模型得出每個面試者可能離開公司的幾率，
並與原資料結果進行對比得出模型評價
